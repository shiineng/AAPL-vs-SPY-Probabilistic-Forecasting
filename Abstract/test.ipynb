# %%
from market_test import overall_analysis

overall_analysis("SPY", "2015-03-21", "2026-03-21", "Close", 653.28, 287, 10000, 'blue', 'pink')
overall_analysis("AVGO", "2015-03-21", "2026-03-21", "Close", 313.1, 287, 10000, 'red', 'purple')
# Out:
# AIC TEST:
#    Distribution:          AIC          BIC  \
# 3      johnsonsu  7576.461295  7600.160479
# 4  genhyperbolic  7592.798735  7622.422715
# 1              t  7602.105916  7619.880304
# 2        laplace  7622.306988  7634.156580
# 5      hypsecant  7714.041169  7725.890761
# 7         cauchy  7957.356384  7969.205976
# 6       skewnorm  8476.105118  8493.879506
# 0           norm  8480.461577  8492.311169
#
#                                               Params  Param Quantity
# 3  (-0.08037127121069226, 1.0539297003684247, 0, ...               4
# 4  (-0.5274339867988151, 0.39372740859302197, 0.0...               5
# 1         (2.721401628881673, 0, 0.6454539020658461)               3
# 2                            (0, 0.7294132655978796)               2
# 5                            (0, 0.6278249964368158)               2
# 7                           (0, 0.45294009604280283)               2
# 6        (0.06007690692420274, 0, 1.120610771806104)               3
# ...
